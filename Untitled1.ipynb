# %%
import pandas as pd

# %%
df=pd.read_csv('excess_mortality.csv')
df.head()
# Out:
#   location        date  p_scores_all_ages  p_scores_15_64  p_scores_65_74  \
# 0  Albania  2020-01-31             -10.65             NaN             NaN
# 1  Albania  2020-02-29               2.17             NaN             NaN
# 2  Albania  2020-03-31               0.62             NaN             NaN
# 3  Albania  2020-04-30               3.23             NaN             NaN
# 4  Albania  2020-05-31               6.15             NaN             NaN
#
#    p_scores_75_84  p_scores_85plus  deaths_2020_all_ages  \
# 0             NaN              NaN                2187.0
# 1             NaN              NaN                2018.0
# 2             NaN              NaN                1993.0
# 3             NaN              NaN                1804.0
# 4             NaN              NaN                1803.0
#
#    average_deaths_2015_2019_all_ages  deaths_2015_all_ages  ...  \
# 0                             2447.8                2490.0  ...
# ...

# %%
df[df.location.isin(['Japan'])]
# Out:
#      location        date  p_scores_all_ages  p_scores_15_64  p_scores_65_74  \
# 2896    Japan  2020-01-31              -1.19             NaN             NaN
# 2897    Japan  2020-02-29               0.65             NaN             NaN
# 2898    Japan  2020-03-31               1.18             NaN             NaN
# 2899    Japan  2020-04-30               4.90             NaN             NaN
# 2900    Japan  2020-05-31               2.53             NaN             NaN
# 2901    Japan  2020-06-30               2.76             NaN             NaN
# 2902    Japan  2020-07-31               1.91             NaN             NaN
# 2903    Japan  2020-08-31               6.19             NaN             NaN
# 2904    Japan  2020-09-30               5.00             NaN             NaN
# 2905    Japan  2020-10-31               6.42             NaN             NaN
# 2906    Japan  2020-11-30               3.99             NaN             NaN
# ...

# %%
ls=df['location'].value_counts().index.to_list()

# %%
ls.sort()

# %%
ls
# Out:
# ['Albania',
#  'Andorra',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bermuda',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England & Wales',
#  'Estonia',
#  'Faeroe Islands',
#  'Finland',
#  'France',
#  'French Guiana',
#  'French Polynesia',
#  'Georgia',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Guadeloupe',
#  'Guatemala',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'Iran',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Latvia',
#  'Lebanon',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao',
#  'Malaysia',
#  'Malta',
#  'Martinique',
#  'Mauritius',
#  'Mayotte',
# ...
